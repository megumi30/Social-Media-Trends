# %%
import pandas as pd
import selenium
from selenium import webdriver as wb
import time
def get_flipkart():
	webD = wb.Chrome()
	webD.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

	prod_links= []
	i = 0
	while(i < 25):
		try:
			ProductinfoList = webD.find_elements_by_class_name("_2kHMtA")
			for item in ProductinfoList:

				prod = item.find_element_by_tag_name("a")
				prod_links.append(prod.get_attribute("href"))

			page_nav = webD.find_element_by_class_name("yFHi8N")
			butts = page_nav.find_elements_by_tag_name("a")[-1]
			butts.click()
		except:
			pass
		time.sleep(0.5)

		i += 1
    
	no_of_revs=[]
	names=[]
	ratings=[]
	image_links=[]
        
	for link in prod_links:
		webD.get(link)
		time.sleep(0.5)

		try:
			reviews = webD.find_elements_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[2]/span[2]/span/span[3]").text
			name = webD.find_elements_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[1]").text
			rating= webD.find_elements_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[2]/div/div/div/a/div[2]/div[1]/div[2]/span[2]/span/span[1]").text

            
			ProductinfoList = webD.find_elements_by_class_name("CXW8mj")
			for item in ProductinfoList:

				img = item.find_element_by_tag_name("img")
				img_links.append(img.get_attribute("src"))


            
			no_of_revs.append(reviews)
			names.append(name)
			ratings.append(rating)  

		except:
			pass               
            
            
        

	df_flipkart = pd.DataFrame(columns=["name", "reviews", "ratings", "image_links"])
	df_flipkart["name"] = names
	df_flipkart["reviews"] = no_of_revs
	df_flipkart["ratings"] = ratings
	df_flipkart["image_links"] = image

	df_flipkart.to_csv("df_flipkart.csv")




get_flipkart()
# Out:
# [[]]
# [[], []]
# [[], [], []]
# [[], [], [], []]
# [[], [], [], [], []]
# [[], [], [], [], [], []]
# [[], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# ...
